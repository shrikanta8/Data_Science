# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# DROP a column

# %%
# x axis is termed as 0 AND y axis is termed as 1

# %%
# df.drop('Survived') #give error as we haven't defined a axis

# %%
df.drop('Survived',axis=1)    #not deleting permanently
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#delete permanently
df = df.drop('Survived',axis=1)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# other way
df.drop('Pclass',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  38.0      1      0          PC 17599  71.2833   C85        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  35.0      1      0            113803  53.1000  C123        S
# 4  35.0      0      0            373450   8.0500   NaN        S

# %%
# DROP A ROW

# %%
df.drop(2)   
#not permanent 
#axis is 0 by default
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# 5              6                                   Moran, Mr. James    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
df.drop(2,inplace=True)

# %%
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# 5              6                                   Moran, Mr. James    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
# making a column as index

# %%
df.set_index("Name")     #not permanent
# Out:
#                                                     PassengerId     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                       1    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2  female  38.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4  female  35.0
# Allen, Mr. William Henry                                      5    male  35.0
# Moran, Mr. James                                              6    male   NaN
# ...                                                         ...     ...   ...
# Montvila, Rev. Juozas                                       887    male  27.0
# Graham, Miss. Margaret Edith                                888  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                    889  female   NaN
# Behr, Mr. Karl Howell                                       890    male  26.0
# Dooley, Mr. Patrick                                         891    male  32.0
#
# ...

# %%
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# 5              6                                   Moran, Mr. James    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
df.set_index("Name",inplace=True)     # permanent

# %%
df
# Out:
#                                                     PassengerId     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                       1    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2  female  38.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4  female  35.0
# Allen, Mr. William Henry                                      5    male  35.0
# Moran, Mr. James                                              6    male   NaN
# ...                                                         ...     ...   ...
# Montvila, Rev. Juozas                                       887    male  27.0
# Graham, Miss. Margaret Edith                                888  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                    889  female   NaN
# Behr, Mr. Karl Howell                                       890    male  26.0
# Dooley, Mr. Patrick                                         891    male  32.0
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId     Sex  \
# 0                              Braund, Mr. Owen Harris            1    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2  female
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4  female
# 3                             Allen, Mr. William Henry            5    male
# 4                                     Moran, Mr. James            6    male
# ..                                                 ...          ...     ...
# 885                              Montvila, Rev. Juozas          887    male
# 886                       Graham, Miss. Margaret Edith          888  female
# 887           Johnston, Miss. Catherine Helen "Carrie"          889  female
# 888                              Behr, Mr. Karl Howell          890    male
# 889                                Dooley, Mr. Patrick          891    male
#
# ...

# %%
d = {
    'key1': [3,4,5,6],
    'key2': [36,7,8,9],
    'key3': [9,0,2,3]
}

# %%
# converting dictionary to data frame
# key becomes column
# len of value must be same

# %%
data1 = pd.DataFrame(d)

# %%
data1
# Out:
#    key1  key2  key3
# 0     3    36     9
# 1     4     7     0
# 2     5     8     2
# 3     6     9     3
