# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("services.csv")

# %%
df.head()     #by default pandas treat first row as the name of columns given
#it gives first 5 rows
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
#if we don't have first row as names of column then set header to None

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
df.tail()
#it gives last 5 rows
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
type(df)
# dataframe (tabular structre of data)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns    #name of columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
list(df.columns)    #name of columns in list
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df['audience']   #selecting a column
# Out:
# 0     Older adults age 55 or over, ethnic minorities...
# 1          Residents of San Mateo County age 55 or over
# 2     Older adults age 55 or over who can benefit fr...
# 3     Parents, children, families with problems of c...
# 4     Low-income working families with children tran...
# 5                                               Any age
# 6     Older adults who have memory or sensory loss, ...
# 7     Senior citizens age 60 or over, disabled indiv...
# 8        Ethnic minorities, especially Spanish speaking
# 9                                                   NaN
# 10                                                  NaN
# 11    Adults, parents, children in 1st-12th grades i...
# 12                                                  NaN
# 13    Individuals or families with low or no income ...
# 14    Adult alcoholic/drug addictive men and women w...
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
type(df['audience'])   #series is  equivalent to list
#a single row/column in pandas is series
# Out:
# pandas.core.series.Series

# %%
list(df['audience'])
# Out:
# ['Older adults age 55 or over, ethnic minorities and low-income persons',
#  'Residents of San Mateo County age 55 or over',
#  'Older adults age 55 or over who can benefit from counseling',
#  'Parents, children, families with problems of custody disputes, domestic violence or substance abuse, families going through a separation or divorce',
#  'Low-income working families with children transitioning from welfare to work and poor or who do not have access to conventional credit',
#  'Any age',
#  'Older adults who have memory or sensory loss, mobility limitations and may be lonely and in need of socialization',
#  'Senior citizens age 60 or over, disabled individuals age 18-59',
#  'Ethnic minorities, especially Spanish speaking',
#  nan,
#  nan,
#  'Adults, parents, children in 1st-12th grades in the Redwood City school districta',
#  nan,
#  'Individuals or families with low or no income and/or trying to obtain public assistance',
# ...

# %%
#in series we are able to see default index, but not in list

# %%
df[['status']]       #passing column name as list
# Out:
#       status
# 0     active
# 1     active
# 2     active
# 3     active
# 4     active
# 5     active
# 6     active
# 7     active
# 8     active
# 9     active
# 10    active
# 11    active
# 12    active
# 13    active
# 14    active
# 15    active
# 16    active
# 17    active
# 18    active
# 19   defunct
# 20  inactive
# 21    active
# 22    active

# %%
type(df[['status']] )
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
# df['eligibility', 'fees']      #it will give error
df[['eligibility', 'fees','taxonomy_ids']]
# Out:
#                                           eligibility  \
# 0   Age 55 or over for most programs, age 60 or ov...
# 1   Age 55 or over, county resident and willing an...
# 2         Resident of San Mateo County age 55 or over
# 3                                                None
# 4   Eligibility: Low-income family with legal cust...
# 5                                                None
# 6                                      Age 18 or over
# 7             Homebound person unable to cook or shop
# 8     Resident of California to obtain a library card
# 9             Resident of California to obtain a card
# 10  Resident of California to obtain a library car...
# 11  English-speaking adult reading at or below 7th...
# 12    Resident of California to obtain a library card
# 13  None for most services. For emergency assistan...
# 14  Age 21-60, detoxed, physically able and willin...
# 15                      None for emergency assistance
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
#READING FROM EXCEL SHEET

# %%
df1 = pd.read_excel("LUSID Excel - Setting up your market data.xlsx")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df1[[ 'Unnamed: 5', 'Unnamed: 6']]
# Out:
#                     Unnamed: 5  Unnamed: 6
# 0                          NaN         NaN
# 1                          NaN         NaN
# 2                          NaN         NaN
# 3                          NaN         NaN
# 4                          NaN         NaN
# 5                          NaN         NaN
# 6                          NaN         NaN
# 7                          NaN         NaN
# 8                          NaN         NaN
# 9                          NaN         NaN
# 10                         NaN         NaN
# 11                         NaN         NaN
# 12                         NaN         NaN
# 13                         NaN         NaN
# 14                         NaN         NaN
# 15         2019-04-10 00:00:00         NaN
# 16                         NaN         NaN
# 17         2019-04-10 00:00:00         NaN
# 18                         NaN         NaN
# 19             13:30:45.550000         NaN
# 20                         NaN         NaN
# ...

# %%
# reading from a link

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(df2['Survived'])
# Out:
# pandas.core.series.Series

# %%
df2[['Survived', 'Pclass', 'Name']]
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
# [891 rows x 3 columns]

# %%
df2.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
# reading from a website having table type data

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 54.2 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
import pandas as pd

# %%
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
#it reads only table data in form of a list

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3 = url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.tail(2)
# Out:
#       Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 673  491   Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492  Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [2 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3[[ 'Player', 'Pos', 'Age']]
# Out:
#              Player Pos Age
# 0        Quincy Acy  PF  24
# 1      Jordan Adams  SG  20
# 2      Steven Adams   C  21
# 3       Jeff Adrien  PF  28
# 4     Arron Afflalo  SG  29
# ..              ...  ..  ..
# 670  Thaddeus Young  PF  26
# 671  Thaddeus Young  PF  26
# 672  Thaddeus Young  PF  26
# 673     Cody Zeller   C  22
# 674    Tyler Zeller   C  25
#
# [675 rows x 3 columns]

# %%
# storing data in file system

# %%
df3.to_csv("players.csv")  #if we don't want to store the index of row then do index=False

# %%
# set column:None if we don't want to store columns name
